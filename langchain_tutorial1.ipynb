# %%
from langchain_google_genai import GoogleGenerativeAI
#from langchain_google_genai import GoogleGenerativeAIChat
from dotenv import load_dotenv
from google import genai
import os

load_dotenv()
# Out:
# False

# %%
api_key = 'AIzaSyBc80F7hbYRkeq2_82yUNw3ynbj_QPm-q8'
client = GoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key = api_key)
#client = genai.Client(api_key="YOUR_API_KEY")
response = client.invoke("What is the capital of France?")
print("\nResponse from Model:")
print(response)
# Out:
# Response from Model:
# The capital of France is **Paris**.

# %%
def invoke_model(prompt):
    response = client.invoke(prompt)
    return response

# %%
prompt = "What is the capital of France?"
response = chat_model.invoke(prompt)
print("\nResponse from Model:")
print(response)

from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template( """ Based on the following context, answer the question at the end. 
                                              If you don't know the answer, say you don't know. 
                                              context: {context}
                                              question: {question}"""
                                              )

formatted_prompt = prompt_template.invoke(input={"context":"France is a country in Europe.", "question":"What is the capital of Germany?"})
response = chat_model.invoke(formatted_prompt)
print("\nResponse from Model:")
print(response)
# Out:
# Response from Model:
# The capital of France is **Paris**.
#
# Response from Model:
# I don't know.

# %%
from langchain_core.prompts import PromptTemplate


# prompt_template = PromptTemplate.from_template( """ Based on the following context, answer the question at the end. 
#                                               If you don't know the answer, say you don't know. 
#                                               Context: {context}
#                                               user_question: {question}"""
#                                               )

# prompt_template.invoke(context="France is a country in Europe.", question="What is the capital of Germany?")
# response = chat_model.invoke(prompt_template)
# print("\nResponse from Model:")
# print(response)
# */

from langchain_core.prompts import ChatMessagePromptTemplate
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
chat_prompt = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate.from_template(
        "Based on the following context, answer the question at the end. "
        "If you don't know the answer, say you don't know."
    ),
    HumanMessagePromptTemplate.from_template(
        "Context: {context}\nuser_question: {question}"
    ),
])

chat = chat_prompt.format_prompt(
    context="France is a country in Europe.",
    question="What is the capital of France?",
)
response = chat_model.invoke(chat)
print("\nResponse from Model:")
print(response)
# Out:
# Response from Model:
# I don't know.

# %%
from pydantic import BaseModel, Field
from langchain_google_genai import ChatGoogleGenerativeAI

api_key = 'AIzaSyBc80F7hbYRkeq2_82yUNw3ynbj_QPm-q8'
class provideJustification(BaseModel):
    question: str = Field(description="The question to be answered.")
    answer: str = Field(description="The answer to the question.")
    justification: str = Field(description="A justification for the answer provided.")

api_key = 'AIzaSyBc80F7hbYRkeq2_82yUNw3ynbj_QPm-q8'
client = GoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key = api_key)

structured_answer = client.with_structured_output(provideJustification)
structured_respone = structured_answer.invoke("Which is first, the egg or the chicken?")
print("\nStructured Response from Model:")
print(structured_respone)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[70], line 15
#      11 client = GoogleGenerativeAI(
#      12     model="gemini-2.5-flash",
#      13     api_key = api_key)
#      14
# ---> 15 structured_answer = client.with_structured_output(provideJustification)
#      16 structured_respone = structured_answer.invoke("Which is first, the egg or the chicken?")
#      17 print("\nStructured Response from Model:")
#      18 print(structured_respone)
#
# File d:\Code\Agentic AI\langchain_env\Lib\site-packages\langchain_core\language_models\base.py:302, in BaseLanguageModel.with_structured_output(self, schema, **kwargs)
#     299 """Not implemented on this class."""
#     300 # Implement this on child class if there is a way of steering the model to
#     301 # generate responses that match a given schema.
# --> 302 raise NotImplementedError
#
# NotImplementedError:

# %%
import langchain
import langchain_google_genai

print(langchain.__version__)
import importlib.metadata

print(langchain.__version__)
try:
    print(importlib.metadata.version("langchain-google-genai"))
except importlib.metadata.PackageNotFoundError:
    print(importlib.metadata.version("langchain_google_genai"))
# Out:
# 1.3.1
# 1.3.1
# 2.1.4
